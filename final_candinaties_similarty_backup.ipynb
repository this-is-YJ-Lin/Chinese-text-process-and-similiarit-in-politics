# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Mar  1 19:09:26 2017

@author: user
"""


import pyodbc
import jieba

from math import*
import codecs
from nltk import word_tokenize
import os #讀取程式目前路徑用
import sys #為了能夠吃進主程式外部輸進的參數
import nltk #引入自然語言處理模組
import io #檔案io
from nltk.corpus import stopwords #去無用字
import re #需要用正則表示式移除標點與數字
from nltk.corpus import wordnet as wn #2013/10/26改用wordnet來做字根還原
from nltk.tokenize import word_tokenize
import json
import numpy as np
import numpy.linalg as LA
import string
import csv
from pandas import Series, DataFrame
import pandas as pd
print("-----STAR-----")
print("try to link with DataBase:cate_test......")
cnxn = pyodbc.connect("DRIVER={SQL Server};SERVER=LEAVES-PC\SA000;DATABASE=cate_test;UID=sa;PWD=00000000")
cursor = cnxn.cursor()
print("sccessful link")

cursor.execute("select top 3 [BulletinPlatform] from [cate_test].[dbo].[20161020001_all_candinates]")
results = cursor.fetchall()


count=0 
for i in results:
    count+=1
    #print ('%d:%s' % (count, i))
print("getting data sccessful")

def getDocDistance(a, b):
    if LA.norm(a)==0 or LA.norm(b)==0:
        return -1  
    return round(np.inner(a, b) / (LA.norm(a) * LA.norm(b)), 5) 
def getDocSimilarity(wordFrequencyPair, minTimes=1):
    #v1 = var1
    #v2 = var2
    result = 0
    try:
        result = getDocDistance(v1, v2)
    except(RuntimeError, TypeError, NameError):
        pass        
    return result

with open('tesst.csv', 'w', newline='') as f: 
    spamwriter = csv.writer(f, dialect='excel')
    headers = ['i', 'j', 'Similarity','i text','j text']
    spamwriter.writerow(headers)
    print("the csv document has created ")
    print("processing...........")
    for i in range(0 , len(results)):
        for j in range(i+1 ,len(results)):      
            for word1 in results[i]:                      
                deletepunc = [u'〔',u'〕',u'〝',u'〞',u'『 ',u'』',u'〈',u'〉',u'\\',u'（', u'）',u'～',u'u3000',u'"',u'&gt',u'&lt',u';',u'，', u'。', u'、', u'；', u'：', u'?', u'「', u'」', u'%', u'.', u',', u'？', u'-', u'~',u'!',u'！', u'&nbsp', u'<BR>', u'“', u'”', u'【', u'】', u'《', u'》',u'：',u'●',u'(',u')',u'；']
                for chin in deletepunc:
                    word1 = word1.replace(chin, ' ')
                result= jieba.cut(word1) 
                result1 = " ".join(result)
                print(''result1)
                file1 = nltk.word_tokenize(result1)
                print(file1)
                trainTokenFrequency = nltk.FreqDist(file1)
                print(trainTokenFrequency)
            for word2 in results[j]:             
                deletepunc = [u'〔',u'〕',u'〝',u'〞',u'『 ',u'』',u'〈',u'〉',u'\\',u'（', u'）',u'～',u'u3000',u'"',u'&gt',u'&lt',u';',u'，', u'。', u'、', u'；', u'：', u'?', u'「', u'」', u'%', u'.', u',', u'？', u'-', u'~',u'!',u'！', u'&nbsp', u'<BR>', u'“', u'”', u'【', u'】', u'《', u'》',u'：',u'●',u'(',u')',u'；']
                for chin in deletepunc:
                    word2 = word2.replace(chin, ' ')
                result= jieba.cut(word2) 
                result2 = " ".join(result)
                file2 = nltk.word_tokenize(result2)
                testTokenFrequency = nltk.FreqDist(file2) 
            
            wordFrequencyPair = [trainTokenFrequency, testTokenFrequency]
            
            minTimes=1
            dict1 = {}
            for key in wordFrequencyPair[0].keys():
                if wordFrequencyPair[0].get(key, 0) >= minTimes:
                    dict1[key] = wordFrequencyPair[0].get(key, 0)
            dict2 = {}
            for key in wordFrequencyPair[1].keys():
                if wordFrequencyPair[1].get(key, 0) >= minTimes:
                    dict2[key] = wordFrequencyPair[1].get(key, 0)
            for key in dict2.keys():
                if dict1.get(key, 0) == 0:   #第一個字典中如果沒有第二字典中的字就把沒有的字加進去並設為0
                    dict1[key] = 0
            for key in dict1.keys():
                if dict2.get(key, 0) == 0:
                    dict2[key] = 0
            v1 = []
            for w1 in sorted(dict1.keys()):
                v1.append(dict1.get(w1))
            v2 = []    
            for w2 in sorted(dict2.keys()):
                v2.append(dict2.get(w2))
                
            def getDocSimilarity(wordFrequencyPair, minTimes=1):
                result = 0
                try:                
                    result = getDocDistance(v1, v2)
                    #print("getDocDistance try")
                except(RuntimeError, TypeError, NameError):
                    pass
                return result    
            data = [( i , j , getDocSimilarity(wordFrequencyPair, 1),result1,result2)]   
            spamwriter.writerows(data)       #寫入csv
print("-----FINISH-----")
f.close()
# Out:
# -----STAR-----
# try to link with DataBase:cate_test......
# sccessful link
# getting data sccessful
# the csv document has created
# processing...........
# 為 了 下一代   讓 真正 的   專業 治安 立委   為國會 帶來 正向 力量       一   守護 孩子   建構 安心 校園 環境       １     推動 制定   K 他命 及 新興 毒品 特別 條例         針 對 製 販 毒 者   加重 刑責   另外 專設 毒品 法院   協助 誤入 吸毒 的 學子   在 不 脫離 教育 下   提供 戒毒 輔導以 取代 刑責         ２     全國小學 廣設 紅外線 電子 圍籬       推動 小學加 裝紅 外線 感應器   將校園 監視 畫面 與 派出所 連線   若有 異常 入侵 可 立即 通知 及 應變         二   保障 婦女   建置 友善 育兒 及 安全 空間       １     蚊子 教室 轉型 為 公托 中心   建置 友善 育兒 空間       全面 利用 少子 化 多出 來 的 學校 空間   設置 公托 中心   推動 並獎勵 公   私場域 設置 哺乳室   親子 廁所   停車區 等 友善 育兒 環境         ２     制定   反 跟 蹤 騷 擾 法     面對 科技 發達 衍生   跟 蹤 及 通 訊 騷 擾     現有 法令 已無法 因應 此 一 新型 態 犯罪 行為   應 仿效 英美 日 制定 專法 保護婦 女 安全         三   爭取 青年 世代 賦稅 公平   建構 全國   退休 族 人才 媒合 平台         １     力抗 低薪 困境   推動 青年 低薪 免繳 所得 稅   擴大獎勵 大 企業 擴 增產學 合作 的 名額   給予 青年 順利 起步 的 機會         ２     活 用 退休 族       因應 高齡化 及 勞動力 不足 問題   並讓 退休 人才 回流   傳承 企業 優勢   政府 應為 55 歲 以上 已 領取 退休金 或 老年 給付 有 就業 需求者   建構 專屬求 才 求職 服務及 就業 創業諮詢 的 平台   並推動 中 高齡者 職務 再 設計   促成 世代 交流 與 合作         四   保障 警消 權益   爭取 警消 超勤 加班 實報 實銷
# ['為', '了', '下一代', '讓', '真正', '的', '專業', '治安', '立委', '為國會', '帶來', '正向', '力量', '一', '守護', '孩子', '建構', '安心', '校園', '環境', '１', '推動', '制定', 'K', '他命', '及', '新興', '毒品', '特別', '條例', '針', '對', '製', '販', '毒', '者', '加重', '刑責', '另外', '專設', '毒品', '法院', '協助', '誤入', '吸毒', '的', '學子', '在', '不', '脫離', '教育', '下', '提供', '戒毒', '輔導以', '取代', '刑責', '２', '全國小學', '廣設', '紅外線', '電子', '圍籬', '推動', '小學加', '裝紅', '外線', '感應器', '將校園', '監視', '畫面', '與', '派出所', '連線', '若有', '異常', '入侵', '可', '立即', '通知', '及', '應變', '二', '保障', '婦女', '建置', '友善', '育兒', '及', '安全', '空間', '１', '蚊子', '教室', '轉型', '為', '公托', '中心', '建置', '友善', '育兒', '空間', '全面', '利用', '少子', '化', '多出', '來', '的', '學校', '空間', '設置', '公托', '中心', '推動', '並獎勵', '公', '私場域', '設置', '哺乳室', '親子', '廁所', '停車區', '等', '友善', '育兒', '環境', '２', '制定', '反', '跟', '蹤', '騷', '擾', '法', '面對', '科技', '發達', '衍生', '跟', '蹤', '及', '通', '訊', '騷', '擾', '現有', '法令', '已無法', '因應', '此', '一', '新型', '態', '犯罪', '行為', '應', '仿效', '英美', '日', '制定', '專法', '保護婦', '女', '安全', '三', '爭取', '青年', '世代', '賦稅', '公平', '建構', '全國', '退休', '族', '人才', '媒合', '平台', '１', '力抗', '低薪', '困境', '推動', '青年', '低薪', '免繳', '所得', '稅', '擴大獎勵', '大', '企業', '擴', '增產學', '合作', '的', '名額', '給予', '青年', '順利', '起步', '的', '機會', '２', '活', '用', '退休', '族', '因應', '高齡化', '及', '勞動力', '不足', '問題', '並讓', '退休', '人才', '回流', '傳承', '企業', '優勢', '政府', '應為', '55', '歲', '以上', '已', '領取', '退休金', '或', '老年', '給付', '有', '就業', '需求者', '建構', '專屬求', '才', '求職', '服務及', '就業', '創業諮詢', '的', '平台', '並推動', '中', '高齡者', '職務', '再', '設計', '促成', '世代', '交流', '與', '合作', '四', '保障', '警消', '權益', '爭取', '警消', '超勤', '加班', '實報', '實銷']
# <FreqDist with 207 samples and 264 outcomes>
# 為 了 下一代   讓 真正 的   專業 治安 立委   為國會 帶來 正向 力量       一   守護 孩子   建構 安心 校園 環境       １     推動 制定   K 他命 及 新興 毒品 特別 條例         針 對 製 販 毒 者   加重 刑責   另外 專設 毒品 法院   協助 誤入 吸毒 的 學子   在 不 脫離 教育 下   提供 戒毒 輔導以 取代 刑責         ２     全國小學 廣設 紅外線 電子 圍籬       推動 小學加 裝紅 外線 感應器   將校園 監視 畫面 與 派出所 連線   若有 異常 入侵 可 立即 通知 及 應變         二   保障 婦女   建置 友善 育兒 及 安全 空間       １     蚊子 教室 轉型 為 公托 中心   建置 友善 育兒 空間       全面 利用 少子 化 多出 來 的 學校 空間   設置 公托 中心   推動 並獎勵 公   私場域 設置 哺乳室   親子 廁所   停車區 等 友善 育兒 環境         ２     制定   反 跟 蹤 騷 擾 法     面對 科技 發達 衍生   跟 蹤 及 通 訊 騷 擾     現有 法令 已無法 因應 此 一 新型 態 犯罪 行為   應 仿效 英美 日 制定 專法 保護婦 女 安全         三   爭取 青年 世代 賦稅 公平   建構 全國   退休 族 人才 媒合 平台         １     力抗 低薪 困境   推動 青年 低薪 免繳 所得 稅   擴大獎勵 大 企業 擴 增產學 合作 的 名額   給予 青年 順利 起步 的 機會         ２     活 用 退休 族       因應 高齡化 及 勞動力 不足 問題   並讓 退休 人才 回流   傳承 企業 優勢   政府 應為 55 歲 以上 已 領取 退休金 或 老年 給付 有 就業 需求者   建構 專屬求 才 求職 服務及 就業 創業諮詢 的 平台   並推動 中 高齡者 職務 再 設計   促成 世代 交流 與 合作         四   保障 警消 權益   爭取 警消 超勤 加班 實報 實銷
# ['為', '了', '下一代', '讓', '真正', '的', '專業', '治安', '立委', '為國會', '帶來', '正向', '力量', '一', '守護', '孩子', '建構', '安心', '校園', '環境', '１', '推動', '制定', 'K', '他命', '及', '新興', '毒品', '特別', '條例', '針', '對', '製', '販', '毒', '者', '加重', '刑責', '另外', '專設', '毒品', '法院', '協助', '誤入', '吸毒', '的', '學子', '在', '不', '脫離', '教育', '下', '提供', '戒毒', '輔導以', '取代', '刑責', '２', '全國小學', '廣設', '紅外線', '電子', '圍籬', '推動', '小學加', '裝紅', '外線', '感應器', '將校園', '監視', '畫面', '與', '派出所', '連線', '若有', '異常', '入侵', '可', '立即', '通知', '及', '應變', '二', '保障', '婦女', '建置', '友善', '育兒', '及', '安全', '空間', '１', '蚊子', '教室', '轉型', '為', '公托', '中心', '建置', '友善', '育兒', '空間', '全面', '利用', '少子', '化', '多出', '來', '的', '學校', '空間', '設置', '公托', '中心', '推動', '並獎勵', '公', '私場域', '設置', '哺乳室', '親子', '廁所', '停車區', '等', '友善', '育兒', '環境', '２', '制定', '反', '跟', '蹤', '騷', '擾', '法', '面對', '科技', '發達', '衍生', '跟', '蹤', '及', '通', '訊', '騷', '擾', '現有', '法令', '已無法', '因應', '此', '一', '新型', '態', '犯罪', '行為', '應', '仿效', '英美', '日', '制定', '專法', '保護婦', '女', '安全', '三', '爭取', '青年', '世代', '賦稅', '公平', '建構', '全國', '退休', '族', '人才', '媒合', '平台', '１', '力抗', '低薪', '困境', '推動', '青年', '低薪', '免繳', '所得', '稅', '擴大獎勵', '大', '企業', '擴', '增產學', '合作', '的', '名額', '給予', '青年', '順利', '起步', '的', '機會', '２', '活', '用', '退休', '族', '因應', '高齡化', '及', '勞動力', '不足', '問題', '並讓', '退休', '人才', '回流', '傳承', '企業', '優勢', '政府', '應為', '55', '歲', '以上', '已', '領取', '退休金', '或', '老年', '給付', '有', '就業', '需求者', '建構', '專屬求', '才', '求職', '服務及', '就業', '創業諮詢', '的', '平台', '並推動', '中', '高齡者', '職務', '再', '設計', '促成', '世代', '交流', '與', '合作', '四', '保障', '警消', '權益', '爭取', '警消', '超勤', '加班', '實報', '實銷']
# <FreqDist with 207 samples and 264 outcomes>
# 現今 百姓 的 抱怨 與 不滿   是 過去 選擇 的 結果   如果 不 改變   不 做 新 的 選擇   面對 未來   如何 能夠 充滿 信心 及 盼望           主要 政見 如下         一   推動 保護 家庭 全民 公投       婚姻家庭 制度 為 社會 形成 與 發展 之 重要 基礎   為 確保 人民 基本 權利 不受 少數 立法者 侵害   特主張 民法 親屬編   婚姻       父母 子女       監護   與   家   四章 中   涉及 夫妻   血緣   與 人倫關 係 的 規定   未經 公民投票 通過 不得 修法         二   推動 家庭 主流 化 政策       督促 政府 建立 家庭 主流 化 政策   制定   健康 家庭 基本法   及   友善 家庭 環境 促進法     鞏固 家庭 功能   支撐 家庭 育兒 扶 老   讓 青年 成家 不孤單         三   強力 支持 青年 發展       建立 青年 公共 創業 平台 及 創客 中心   輔導 青年 創業   並以 身作則 積極 推動   愛家 企業     落實   健康人 權     鼓勵 企業 主重 視員工 的 家庭幸福   締造 友善 就業 環境         四   監督 教育 改革       強化 品格 教育 與 社會 服務學習 優 於 升學主義   提供 多元 教育 選擇   縮 減學用 落差   重視家長 的 教育 參與權   同時 落實   家庭教育 法     提升 父母 親職 能力   幫助 家庭 培育 優秀 下一代         五   保護 環境   避免 過度 開發       我將 推動 低 碳永續 家園 計畫   支持 資源 循環 利用   全面 檢討 監督國 土規劃 和 區域 計畫   促進 土地 資源 合理 分配         六   建構 災防應 變系統       自然 環境   化學 或 人 為 大災難 的 無 預警 發生 令人不安   我將 推動 政府 及民間 建構 災防   通報 及 應 變系統   降低 災害 的 程度         七   根本 解決 治安 問題       以 家庭 為本   強化仁 愛   互助   尊重 等 社會 善良 價值   降低 犯罪率   從 根本 消弭 霸凌及 蓄意 傷人 事件 等 治安 問題
# ['現今', '百姓', '的', '抱怨', '與', '不滿', '是', '過去', '選擇', '的', '結果', '如果', '不', '改變', '不', '做', '新', '的', '選擇', '面對', '未來', '如何', '能夠', '充滿', '信心', '及', '盼望', '主要', '政見', '如下', '一', '推動', '保護', '家庭', '全民', '公投', '婚姻家庭', '制度', '為', '社會', '形成', '與', '發展', '之', '重要', '基礎', '為', '確保', '人民', '基本', '權利', '不受', '少數', '立法者', '侵害', '特主張', '民法', '親屬編', '婚姻', '父母', '子女', '監護', '與', '家', '四章', '中', '涉及', '夫妻', '血緣', '與', '人倫關', '係', '的', '規定', '未經', '公民投票', '通過', '不得', '修法', '二', '推動', '家庭', '主流', '化', '政策', '督促', '政府', '建立', '家庭', '主流', '化', '政策', '制定', '健康', '家庭', '基本法', '及', '友善', '家庭', '環境', '促進法', '鞏固', '家庭', '功能', '支撐', '家庭', '育兒', '扶', '老', '讓', '青年', '成家', '不孤單', '三', '強力', '支持', '青年', '發展', '建立', '青年', '公共', '創業', '平台', '及', '創客', '中心', '輔導', '青年', '創業', '並以', '身作則', '積極', '推動', '愛家', '企業', '落實', '健康人', '權', '鼓勵', '企業', '主重', '視員工', '的', '家庭幸福', '締造', '友善', '就業', '環境', '四', '監督', '教育', '改革', '強化', '品格', '教育', '與', '社會', '服務學習', '優', '於', '升學主義', '提供', '多元', '教育', '選擇', '縮', '減學用', '落差', '重視家長', '的', '教育', '參與權', '同時', '落實', '家庭教育', '法', '提升', '父母', '親職', '能力', '幫助', '家庭', '培育', '優秀', '下一代', '五', '保護', '環境', '避免', '過度', '開發', '我將', '推動', '低', '碳永續', '家園', '計畫', '支持', '資源', '循環', '利用', '全面', '檢討', '監督國', '土規劃', '和', '區域', '計畫', '促進', '土地', '資源', '合理', '分配', '六', '建構', '災防應', '變系統', '自然', '環境', '化學', '或', '人', '為', '大災難', '的', '無', '預警', '發生', '令人不安', '我將', '推動', '政府', '及民間', '建構', '災防', '通報', '及', '應', '變系統', '降低', '災害', '的', '程度', '七', '根本', '解決', '治安', '問題', '以', '家庭', '為本', '強化仁', '愛', '互助', '尊重', '等', '社會', '善良', '價值', '降低', '犯罪率', '從', '根本', '消弭', '霸凌及', '蓄意', '傷人', '事件', '等', '治安', '問題']
# <FreqDist with 206 samples and 271 outcomes>
# -----FINISH-----
